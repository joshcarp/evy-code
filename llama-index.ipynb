# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.core.embeddings import resolve_embed_model
from llama_index.llms.ollama import Ollama
from llama_index.readers.file import CSVReader
from llama_index.readers.huggingface_fs import HuggingFaceFSReader

# load documents
loader = HuggingFaceFSReader()
documents = loader.load_data("datasets/joshcarp/evy-code")

# Load a CSV file
# csv_reader = CSVReader()
# documents = csv_reader.load_data(file=Path("evy_dataset.csv"))
# documents = SimpleDirectoryReader(".", "evy_dataset.csv").load_data()

# Load the dataset from the Hugging Face Hub

# Create the index
# index = VectorStoreIndex.from_documents(documents)



# Create the index

# documents = SimpleDirectoryReader("data").load_file()

# bge embedding model
Settings.embed_model = resolve_embed_model("local:bigcode/starcoder2-3b")

# Settings.embed_model.tokenizer.pad_token = '[PAD]'
# .add_special_tokens({'pad_token': '[PAD]'})
HuggingFaceFSReader

# ollama
Settings.llm = Ollama(model="starcoder2", request_timeout=30.0)

index = VectorStoreIndex.from_documents(
    documents,
)
# Out:
# No sentence-transformers model found with name bigcode/starcoder2-3b. Creating a new one with MEAN pooling.

# %%
from llama_index.readers.huggingface_fs import HuggingFaceFSReader
loader = HuggingFaceFSReader()
documents = loader.load_data("datasets/joshcarp/evy-code")
from datasets import load_dataset
dataset = load_dataset("joshcarp/evy-code")
dataset.train
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['repo_url', 'file_path', 'content'],
#         num_rows: 36
#     })
# })

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 query_engine = index.as_query_engine()
# ----> 2 response = query_engine.query("What did the author do growing up?")
#       3 print(response)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:146, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     144     result = func(*args, **kwargs)
#     145 except BaseException as e:
# --> 146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     147     raise
#     148 else:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:98, in Dispatcher.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96 while c:
#      97     for h in c.span_handlers:
# ---> 98         h.span_drop(
#      99             *args,
#     100             id_=id_,
#     101             bound_args=bound_args,
#     102             instance=instance,
#     103             err=err,
#     104             **kwargs,
#     105         )
#     106     if not c.propagate:
#     107         c = None
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/base.py:77, in BaseSpanHandler.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      67 def span_drop(
#      68     self,
#      69     *args: Any,
#    (...)
#      74     **kwargs: Any,
#      75 ) -> None:
#      76     """Logic for dropping a span i.e. early exit."""
# ---> 77     span = self.prepare_to_drop_span(
#      78         id_=id_, bound_args=bound_args, instance=instance, err=err
#      79     )
#      80     if span:
#      81         if self.current_span_id == id_:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/null.py:71, in NullSpanHandler.prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69 """Logic for droppping a span."""
#      70 if err:
# ---> 71     raise err
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:144, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     142 self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     143 try:
# --> 144     result = func(*args, **kwargs)
#     145 except BaseException as e:
#     146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/base/base_query_engine.py:51, in BaseQueryEngine.query(self, str_or_query_bundle)
#      49     if isinstance(str_or_query_bundle, str):
#      50         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 51     query_result = self._query(str_or_query_bundle)
#      52 dispatcher.event(QueryEndEvent())
#      53 return query_result
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:146, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     144     result = func(*args, **kwargs)
#     145 except BaseException as e:
# --> 146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     147     raise
#     148 else:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:98, in Dispatcher.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96 while c:
#      97     for h in c.span_handlers:
# ---> 98         h.span_drop(
#      99             *args,
#     100             id_=id_,
#     101             bound_args=bound_args,
#     102             instance=instance,
#     103             err=err,
#     104             **kwargs,
#     105         )
#     106     if not c.propagate:
#     107         c = None
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/base.py:77, in BaseSpanHandler.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      67 def span_drop(
#      68     self,
#      69     *args: Any,
#    (...)
#      74     **kwargs: Any,
#      75 ) -> None:
#      76     """Logic for dropping a span i.e. early exit."""
# ---> 77     span = self.prepare_to_drop_span(
#      78         id_=id_, bound_args=bound_args, instance=instance, err=err
#      79     )
#      80     if span:
#      81         if self.current_span_id == id_:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/null.py:71, in NullSpanHandler.prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69 """Logic for droppping a span."""
#      70 if err:
# ---> 71     raise err
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:144, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     142 self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     143 try:
# --> 144     result = func(*args, **kwargs)
#     145 except BaseException as e:
#     146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/query_engine/retriever_query_engine.py:189, in RetrieverQueryEngine._query(self, query_bundle)
#     185 """Answer a query."""
#     186 with self.callback_manager.event(
#     187     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     188 ) as query_event:
# --> 189     nodes = self.retrieve(query_bundle)
#     190     response = self._response_synthesizer.synthesize(
#     191         query=query_bundle,
#     192         nodes=nodes,
#     193     )
#     194     query_event.on_end(payload={EventPayload.RESPONSE: response})
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/query_engine/retriever_query_engine.py:144, in RetrieverQueryEngine.retrieve(self, query_bundle)
#     143 def retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 144     nodes = self._retriever.retrieve(query_bundle)
#     145     return self._apply_node_postprocessors(nodes, query_bundle=query_bundle)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:146, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     144     result = func(*args, **kwargs)
#     145 except BaseException as e:
# --> 146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     147     raise
#     148 else:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:98, in Dispatcher.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96 while c:
#      97     for h in c.span_handlers:
# ---> 98         h.span_drop(
#      99             *args,
#     100             id_=id_,
#     101             bound_args=bound_args,
#     102             instance=instance,
#     103             err=err,
#     104             **kwargs,
#     105         )
#     106     if not c.propagate:
#     107         c = None
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/base.py:77, in BaseSpanHandler.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      67 def span_drop(
#      68     self,
#      69     *args: Any,
#    (...)
#      74     **kwargs: Any,
#      75 ) -> None:
#      76     """Logic for dropping a span i.e. early exit."""
# ---> 77     span = self.prepare_to_drop_span(
#      78         id_=id_, bound_args=bound_args, instance=instance, err=err
#      79     )
#      80     if span:
#      81         if self.current_span_id == id_:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/null.py:71, in NullSpanHandler.prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69 """Logic for droppping a span."""
#      70 if err:
# ---> 71     raise err
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:144, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     142 self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     143 try:
# --> 144     result = func(*args, **kwargs)
#     145 except BaseException as e:
#     146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/base/base_retriever.py:238, in BaseRetriever.retrieve(self, str_or_query_bundle)
#     233 with self.callback_manager.as_trace("query"):
#     234     with self.callback_manager.event(
#     235         CBEventType.RETRIEVE,
#     236         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     237     ) as retrieve_event:
# --> 238         nodes = self._retrieve(query_bundle)
#     239         nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     240         retrieve_event.on_end(
#     241             payload={EventPayload.NODES: nodes},
#     242         )
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:146, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     144     result = func(*args, **kwargs)
#     145 except BaseException as e:
# --> 146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     147     raise
#     148 else:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:98, in Dispatcher.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96 while c:
#      97     for h in c.span_handlers:
# ---> 98         h.span_drop(
#      99             *args,
#     100             id_=id_,
#     101             bound_args=bound_args,
#     102             instance=instance,
#     103             err=err,
#     104             **kwargs,
#     105         )
#     106     if not c.propagate:
#     107         c = None
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/base.py:77, in BaseSpanHandler.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      67 def span_drop(
#      68     self,
#      69     *args: Any,
#    (...)
#      74     **kwargs: Any,
#      75 ) -> None:
#      76     """Logic for dropping a span i.e. early exit."""
# ---> 77     span = self.prepare_to_drop_span(
#      78         id_=id_, bound_args=bound_args, instance=instance, err=err
#      79     )
#      80     if span:
#      81         if self.current_span_id == id_:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/null.py:71, in NullSpanHandler.prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69 """Logic for droppping a span."""
#      70 if err:
# ---> 71     raise err
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:144, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     142 self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     143 try:
# --> 144     result = func(*args, **kwargs)
#     145 except BaseException as e:
#     146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/indices/vector_store/retrievers/retriever.py:97, in VectorIndexRetriever._retrieve(self, query_bundle)
#      94 if self._vector_store.is_embedding_query:
#      95     if query_bundle.embedding is None and len(query_bundle.embedding_strs) > 0:
#      96         query_bundle.embedding = (
# ---> 97             self._embed_model.get_agg_embedding_from_queries(
#      98                 query_bundle.embedding_strs
#      99             )
#     100         )
#     101 return self._get_nodes_with_embeddings(query_bundle)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/base/embeddings/base.py:160, in BaseEmbedding.get_agg_embedding_from_queries(self, queries, agg_fn)
#     154 def get_agg_embedding_from_queries(
#     155     self,
#     156     queries: List[str],
#     157     agg_fn: Optional[Callable[..., Embedding]] = None,
#     158 ) -> Embedding:
#     159     """Get aggregated embedding from multiple queries."""
# --> 160     query_embeddings = [self.get_query_embedding(query) for query in queries]
#     161     agg_fn = agg_fn or mean_agg
#     162     return agg_fn(query_embeddings)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:146, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     144     result = func(*args, **kwargs)
#     145 except BaseException as e:
# --> 146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     147     raise
#     148 else:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:98, in Dispatcher.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96 while c:
#      97     for h in c.span_handlers:
# ---> 98         h.span_drop(
#      99             *args,
#     100             id_=id_,
#     101             bound_args=bound_args,
#     102             instance=instance,
#     103             err=err,
#     104             **kwargs,
#     105         )
#     106     if not c.propagate:
#     107         c = None
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/base.py:77, in BaseSpanHandler.span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      67 def span_drop(
#      68     self,
#      69     *args: Any,
#    (...)
#      74     **kwargs: Any,
#      75 ) -> None:
#      76     """Logic for dropping a span i.e. early exit."""
# ---> 77     span = self.prepare_to_drop_span(
#      78         id_=id_, bound_args=bound_args, instance=instance, err=err
#      79     )
#      80     if span:
#      81         if self.current_span_id == id_:
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/span_handlers/null.py:71, in NullSpanHandler.prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69 """Logic for droppping a span."""
#      70 if err:
# ---> 71     raise err
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:144, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     142 self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     143 try:
# --> 144     result = func(*args, **kwargs)
#     145 except BaseException as e:
#     146     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/core/base/embeddings/base.py:121, in BaseEmbedding.get_query_embedding(self, query)
#     117 dispatcher.event(EmbeddingStartEvent(model_dict=self.to_dict()))
#     118 with self.callback_manager.event(
#     119     CBEventType.EMBEDDING, payload={EventPayload.SERIALIZED: self.to_dict()}
#     120 ) as event:
# --> 121     query_embedding = self._get_query_embedding(query)
#     123     event.on_end(
#     124         payload={
#     125             EventPayload.CHUNKS: [query],
#     126             EventPayload.EMBEDDINGS: [query_embedding],
#     127         },
#     128     )
#     129 dispatcher.event(
#     130     EmbeddingEndEvent(chunks=[query], embeddings=[query_embedding])
#     131 )
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/embeddings/huggingface/base.py:133, in HuggingFaceEmbedding._get_query_embedding(self, query)
#     131 def _get_query_embedding(self, query: str) -> List[float]:
#     132     """Get query embedding."""
# --> 133     return self._embed(query, prompt_name="query")
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/llama_index/embeddings/huggingface/base.py:124, in HuggingFaceEmbedding._embed(self, sentences, prompt_name)
#     118 def _embed(
#     119     self,
#     120     sentences: List[str],
#     121     prompt_name: Optional[str] = None,
#     122 ) -> List[List[float]]:
#     123     """Embed sentences."""
# --> 124     return self._model.encode(
#     125         sentences,
#     126         batch_size=self.embed_batch_size,
#     127         prompt_name=prompt_name,
#     128         normalize_embeddings=self.normalize,
#     129     ).tolist()
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:337, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     333 sentences = [prompt + sentence for sentence in sentences]
#     335 # Some models (e.g. INSTRUCTOR, GRIT) require removing the prompt before pooling
#     336 # Tracking the prompt length allow us to remove the prompt during pooling
# --> 337 tokenized_prompt = self.tokenize([prompt])
#     338 if "input_ids" in tokenized_prompt:
#     339     extra_features["prompt_length"] = tokenized_prompt["input_ids"].shape[-1] - 1
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:569, in SentenceTransformer.tokenize(self, texts)
#     565 def tokenize(self, texts: Union[List[str], List[Dict], List[Tuple[str, str]]]):
#     566     """
#     567     Tokenizes the texts
#     568     """
# --> 569     return self._first_module().tokenize(texts)
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:146, in Transformer.tokenize(self, texts)
#     142 if self.do_lower_case:
#     143     to_tokenize = [[s.lower() for s in col] for col in to_tokenize]
#     145 output.update(
# --> 146     self.tokenizer(
#     147         *to_tokenize,
#     148         padding=True,
#     149         truncation="longest_first",
#     150         return_tensors="pt",
#     151         max_length=self.max_seq_length,
#     152     )
#     153 )
#     154 return output
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2872, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2870     if not self._in_target_context_manager:
#    2871         self._switch_to_input_mode()
# -> 2872     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2873 if text_target is not None:
#    2874     self._switch_to_target_mode()
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2958, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2953         raise ValueError(
#    2954             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2955             f" {len(text_pair)}."
#    2956         )
#    2957     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2958     return self.batch_encode_plus(
#    2959         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2960         add_special_tokens=add_special_tokens,
#    2961         padding=padding,
#    2962         truncation=truncation,
#    2963         max_length=max_length,
#    2964         stride=stride,
#    2965         is_split_into_words=is_split_into_words,
#    2966         pad_to_multiple_of=pad_to_multiple_of,
#    2967         return_tensors=return_tensors,
#    2968         return_token_type_ids=return_token_type_ids,
#    2969         return_attention_mask=return_attention_mask,
#    2970         return_overflowing_tokens=return_overflowing_tokens,
#    2971         return_special_tokens_mask=return_special_tokens_mask,
#    2972         return_offsets_mapping=return_offsets_mapping,
#    2973         return_length=return_length,
#    2974         verbose=verbose,
#    2975         **kwargs,
#    2976     )
#    2977 else:
#    2978     return self.encode_plus(
#    2979         text=text,
#    2980         text_pair=text_pair,
#    (...)
#    2996         **kwargs,
#    2997     )
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:3140, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3123 """
#    3124 Tokenize and prepare for the model a list of sequences or a list of pairs of sequences.
#    3125
#    (...)
#    3136         details in `encode_plus`).
#    3137 """
#    3139 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
# -> 3140 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3141     padding=padding,
#    3142     truncation=truncation,
#    3143     max_length=max_length,
#    3144     pad_to_multiple_of=pad_to_multiple_of,
#    3145     verbose=verbose,
#    3146     **kwargs,
#    3147 )
#    3149 return self._batch_encode_plus(
#    3150     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3151     add_special_tokens=add_special_tokens,
#    (...)
#    3166     **kwargs,
#    3167 )
#
# File ~/miniconda3/envs/llama_index/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2777, in PreTrainedTokenizerBase._get_padding_truncation_strategies(self, padding, truncation, max_length, pad_to_multiple_of, verbose, **kwargs)
#    2775 # Test if we have a padding token
#    2776 if padding_strategy != PaddingStrategy.DO_NOT_PAD and (self.pad_token is None or self.pad_token_id < 0):
# -> 2777     raise ValueError(
#    2778         "Asking to pad but the tokenizer does not have a padding token. "
#    2779         "Please select a token to use as `pad_token` `(tokenizer.pad_token = tokenizer.eos_token e.g.)` "
#    2780         "or add a new pad token via `tokenizer.add_special_tokens({'pad_token': '[PAD]'})`."
#    2781     )
#    2783 # Check that we will truncate to a multiple of pad_to_multiple_of if both are provided
#    2784 if (
#    2785     truncation_strategy != TruncationStrategy.DO_NOT_TRUNCATE
#    2786     and padding_strategy != PaddingStrategy.DO_NOT_PAD
#    (...)
#    2789     and (max_length % pad_to_multiple_of != 0)
#    2790 ):
#
# ValueError: Asking to pad but the tokenizer does not have a padding token. Please select a token to use as `pad_token` `(tokenizer.pad_token = tokenizer.eos_token e.g.)` or add a new pad token via `tokenizer.add_special_tokens({'pad_token': '[PAD]'})`.
